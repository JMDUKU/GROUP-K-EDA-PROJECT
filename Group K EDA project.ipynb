# %%
# Importing necessary Libraries.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from collections import Counter

# %%
df = pd.read_excel(r"C:\Users\GADGET GHANA\Downloads\vgsales.xlsx")

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# showing columns of the database

df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
# Cleaning the columns of the dataset.

df['Publisher'] = df['Publisher'].str.replace('[//]',"")
df['Year'].dropna()
df=df.dropna()
df
# Out:
# C:\Users\GADGET GHANA\AppData\Local\Temp\ipykernel_3752\3423954237.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Publisher'] = df['Publisher'].str.replace('[//]',"")
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# ...

# %%
# Information about the dataframe.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
# The first ten items of the DataFrame.

df.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
# The last ten items of the DataFrame. 

df.tail(10)
# Out:
#         Rank                                               Name Platform  \
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# 16588  2008.0        Puzzle  Majesco Entertainment      0.01      0.00
# ...

# %%
# Description of the entire dataset.

df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    8290.190228   2006.405561      0.265647      0.147731      0.078833
# std     4792.654450      5.832412      0.822432      0.509303      0.311879
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4132.500000   2003.000000      0.000000      0.000000      0.000000
# 50%     8292.000000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.500000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16291.000000  16291.000000
# mean       0.048426      0.540910
# std        0.190083      1.567345
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# ...

# %%
# correlation between Rank and Sales from the various outlets.

corr1 = df[['Rank','NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].corr()
corr1
# Out:
#                   Rank  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank          1.000000 -0.400315 -0.379137 -0.269323    -0.332735
# NA_Sales     -0.400315  1.000000  0.768923  0.451283     0.634518
# EU_Sales     -0.379137  0.768923  1.000000  0.436379     0.726256
# JP_Sales     -0.269323  0.451283  0.436379  1.000000     0.290559
# Other_Sales  -0.332735  0.634518  0.726256  0.290559     1.000000
# Global_Sales -0.426975  0.941269  0.903264  0.612774     0.747964
#
#               Global_Sales
# Rank             -0.426975
# NA_Sales          0.941269
# EU_Sales          0.903264
# JP_Sales          0.612774
# Other_Sales       0.747964
# Global_Sales      1.000000

# %%
# Total number of Games published in each year across the period from 1980 to 2020

year_of_publishment = df.Year.value_counts().sort_values(ascending=False)
year_of_publishment
# Out:
# 2009.0    1431
# 2008.0    1428
# 2010.0    1257
# 2007.0    1201
# 2011.0    1136
# 2006.0    1008
# 2005.0     936
# 2002.0     829
# 2003.0     775
# 2004.0     744
# 2012.0     655
# 2015.0     614
# 2014.0     580
# 2013.0     546
# 2001.0     482
# 1998.0     379
# 2000.0     349
# 2016.0     342
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1983.0      17
# 1989.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1985.0      14
# 1984.0      14
# 1980.0       9
# 2017.0       3
# 2020.0       1
# Name: Year, dtype: int64

# %%
# Years and sales generated

df.groupby(['Year'])[['NA_Sales','EU_Sales','JP_Sales','Other_Sales',
                     'Global_Sales']].sum()
# Out:
#         NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year
# 1980.0     10.59      0.67      0.00         0.12         11.38
# 1981.0     33.40      1.96      0.00         0.32         35.77
# 1982.0     26.92      1.65      0.00         0.31         28.86
# 1983.0      7.76      0.80      8.10         0.14         16.79
# 1984.0     33.28      2.10     14.27         0.70         50.36
# 1985.0     33.73      4.74     14.56         0.92         53.94
# 1986.0     12.50      2.84     19.81         1.93         37.07
# 1987.0      8.46      1.41     11.63         0.20         21.74
# 1988.0     23.87      6.59     15.76         0.99         47.22
# 1989.0     45.15      8.44     18.36         1.50         73.45
# 1990.0     25.46      7.63     14.88         1.40         49.39
# 1991.0     12.76      3.95     14.78         0.74         32.23
# 1992.0     33.87     11.71     28.91         1.65         76.16
# 1993.0     15.12      4.65     25.33         0.89         45.98
# ...

# %%
# Total sales generated by each Game across each of the sales centres(Top 10 games).

group1 = df.groupby(['Name'])[['NA_Sales','EU_Sales','JP_Sales','Other_Sales',
                     'Global_Sales']].sum()
group1.sort_values('Global_Sales',ascending=False).head(10)
# Out:
#                                 NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                         41.49     29.02      3.77         8.46
# Grand Theft Auto V                 23.46     23.04      1.39         8.03
# Super Mario Bros.                  32.48      4.88      6.96         0.99
# Tetris                             26.17      2.95      6.03         0.69
# Mario Kart Wii                     15.85     12.88      3.79         3.31
# Wii Sports Resort                  15.75     11.01      3.28         2.96
# Pokemon Red/Pokemon Blue           11.27      8.89     10.22         1.00
# Call of Duty: Modern Warfare 3     15.58     11.29      0.62         3.35
# New Super Mario Bros.              11.38      9.23      6.50         2.90
# Call of Duty: Black Ops II         14.08     11.05      0.72         3.88
#
#                                 Global_Sales
# Name
# Wii Sports                             82.74
# Grand Theft Auto V                     55.92
# ...

# %%
# Top ten gaming platforms in terms of games published on it.

df.Platform.value_counts().head(10)
# Out:
# DS      2131
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1234
# PSP     1197
# PS      1189
# PC       938
# XB       803
# GBA      786
# Name: Platform, dtype: int64

# %%
# Total sales generated by each gaming platform across the market centres.

platform_group = df.groupby(['Platform'])[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].sum()
platform_group.sort_values('Global_Sales',ascending=False)
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# PS2         572.92    332.63    137.54       190.47       1233.46
# X360        594.33    278.00     12.30        84.67        969.60
# PS3         388.90    340.47     79.21       140.81        949.35
# Wii         497.37    264.35     68.28        79.20        909.81
# DS          388.53    194.05    175.02        60.29        818.91
# PS          334.71    212.38    139.78        40.69        727.39
# GBA         178.43     72.49     46.56         7.51        305.62
# PSP         107.09     67.16     75.89        41.52        291.71
# PS4          96.80    123.70     14.30        43.36        278.10
# PC           92.04    137.35      0.17        24.33        254.70
# GB          113.64     47.51     85.12         8.16        254.42
# XB          182.06     59.65      1.38         8.48        252.09
# NES         125.94     21.15     98.65         5.31        251.07
# ...

# %%
# Top ten publishers in terms of video games published

df.Publisher.value_counts().head(10)
# Out:
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
# THQ                              712
# Nintendo                         696
# Sony Computer Entertainment      682
# Sega                             632
# Take-Two Interactive             412
# Name: Publisher, dtype: int64

# %%
publisher_group = df.groupby(['Publisher'])[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].sum()
publisher_group.sort_values('Global_Sales',ascending=False)
# Out:
#                              NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# Nintendo                       815.75    418.30    454.99        95.19
# Electronic Arts                584.22    367.38     13.98       127.63
# Activision                     426.01    213.72      6.54        74.79
# Sony Computer Entertainment    265.22    187.55     74.10        80.40
# Ubisoft                        252.81    163.03      7.33        50.16
# ...                               ...       ...       ...          ...
# Epic Games                       0.01      0.00      0.00         0.00
# Paradox Development              0.00      0.01      0.00         0.00
# Rain Games                       0.00      0.01      0.00         0.00
# Ascaron Entertainment            0.00      0.01      0.00         0.00
# Commseed                         0.00      0.00      0.01         0.00
#
#                              Global_Sales
# Publisher
# Nintendo                          1784.43
# ...

# %%
# Number of times a game has been published over the period from 1980 to 2020.

df.Name.value_counts().head(10)
# Out:
# Need for Speed: Most Wanted    12
# FIFA 14                         9
# Ratatouille                     9
# LEGO Marvel Super Heroes        9
# Cars                            8
# LEGO The Hobbit                 8
# Monopoly                        8
# FIFA Soccer 13                  8
# Madden NFL 08                   8
# Angry Birds Star Wars           8
# Name: Name, dtype: int64

# %%
# Top ten games in terms of rank.

Top_ten_games = df.groupby(['Name'])['Rank'].mean().sort_values(ascending=True).head(10)
Top_ten_games
# Out:
# Name
# Wii Sports                    1.0
# Mario Kart Wii                3.0
# Wii Sports Resort             4.0
# Pokemon Red/Pokemon Blue      5.0
# New Super Mario Bros.         7.0
# Wii Play                      8.0
# New Super Mario Bros. Wii     9.0
# Duck Hunt                    10.0
# Nintendogs                   11.0
# Mario Kart DS                12.0
# Name: Rank, dtype: float64

# %%
# Number of video games published under each Genre.

df.Genre.value_counts()
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genre, dtype: int64

# %%
# Total sales generated by each genre over the market centres.

group = df.groupby(['Genre'])[['NA_Sales','EU_Sales','JP_Sales','Other_Sales',
                     'Global_Sales']].sum()
group
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Action          861.77    516.48    158.65       184.92       1722.84
# Adventure       101.93     63.74     51.99        16.70        234.59
# Fighting        220.74    100.00     87.15        36.19        444.05
# Misc            396.92    211.77    106.67        73.92        789.87
# Platform        445.99    200.65    130.65        51.51        829.13
# Puzzle          122.01     50.52     56.68        12.47        242.21
# Racing          356.93    236.31     56.61        76.68        726.76
# Role-Playing    326.50    187.57    350.29        59.38        923.83
# Shooter         575.16    310.45     38.18       101.90       1026.20
# Simulation      181.78    113.02     63.54        31.36        389.98
# Sports          670.09    371.34    134.76       132.65       1309.24
# Strategy         67.83     44.84     49.10        11.23        173.27

# %%
genre_dict = dict(Counter(df['Genre']))
genre_dict
# Out:
# {'Sports': 2304,
#  'Platform': 875,
#  'Racing': 1225,
#  'Role-Playing': 1470,
#  'Puzzle': 570,
#  'Misc': 1686,
#  'Shooter': 1282,
#  'Simulation': 848,
#  'Action': 3251,
#  'Fighting': 836,
#  'Adventure': 1274,
#  'Strategy': 670}

# %%
# Number of Games published under each Genre

plt.figure(figsize=(10,5))
plt.bar(genre_dict.keys(), genre_dict.values(), color='blue')
plt.xlabel('Genre')
plt.ylabel('Frequency')
plt.title('Number of Games published under each Genre')
plt.xticks(rotation=45)
plt.show()

# %%
group_dict = dict(Counter(df['Year']))
group_dict
# Out:
# {2006.0: 1008,
#  1985.0: 14,
#  2008.0: 1428,
#  2009.0: 1431,
#  1996.0: 263,
#  1989.0: 17,
#  1984.0: 14,
#  2005.0: 936,
#  1999.0: 338,
#  2007.0: 1201,
#  2010.0: 1257,
#  2013.0: 546,
#  2004.0: 744,
#  1990.0: 16,
#  1988.0: 15,
#  2002.0: 829,
#  2001.0: 482,
#  2011.0: 1136,
#  1998.0: 379,
#  2015.0: 614,
#  2012.0: 655,
#  2014.0: 580,
#  1992.0: 43,
#  1997.0: 289,
#  1993.0: 60,
#  1994.0: 121,
#  1982.0: 36,
#  2003.0: 775,
#  1986.0: 21,
#  2000.0: 349,
#  1995.0: 219,
#  2016.0: 342,
#  1991.0: 41,
#  1981.0: 46,
#  1987.0: 16,
#  1980.0: 9,
#  1983.0: 17,
#  2020.0: 1,
#  2017.0: 3}

# %%
# Total number of published in each year

plt.figure(figsize=(10,5))
plt.bar(group_dict.keys(), group_dict.values(), color='brown')
plt.xlabel('Name of Games')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %%
# Top ten most published game

Top_ten_games = dict(Counter(df['Name']).most_common(10))
Top_ten_games
# Out:
# {'Need for Speed: Most Wanted': 12,
#  'FIFA 14': 9,
#  'LEGO Marvel Super Heroes': 9,
#  'Ratatouille': 9,
#  'FIFA Soccer 13': 8,
#  'FIFA 15': 8,
#  'Madden NFL 07': 8,
#  'LEGO Star Wars II: The Original Trilogy': 8,
#  'Madden NFL 08': 8,
#  'Monopoly': 8}

# %%
# Graph for the top ten most published games over the period from 1980 to 2020.

plt.figure(figsize=(10,5))
plt.bar(Top_ten_games.keys(), Top_ten_games.values(), color='brown')
plt.xlabel('Name of Games')
plt.ylabel('Frequency')
plt.title('Top 10 most published Game')
plt.xticks(rotation=90)
plt.show()

# %%
# Graphical presentation of total sales from each sales outlets
sum_values = group.sum()

plt.figure(figsize=(9,5))
plt.bar(sum_values.index, sum_values.values, color='blue')
plt.xlabel('Sales outlets')
plt.ylabel('Frequency')
plt.title('Total Sales from each Market')
plt.xticks(rotation=45)
plt.show()

# %%
# Graphical plotting of sales generated by each Genre
fig, ax = plt.subplots(figsize=(10,5))
group.plot(kind='bar', ax=ax,width=0.9)
ax.set_xlabel('Genre')
ax.set_ylabel('Sales from various markets')
ax.set_title('Sales Generated by each Genre')
plt.show()
